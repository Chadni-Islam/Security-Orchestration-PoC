# %%
# https://spacy.io/usage/linguistic-features
# https://www.dataquest.io/blog/tutorial-text-classification-in-python-using-spacy/
# https://nlpforhackers.io/complete-guide-to-spacy/
import spacy
import pandas as pd
#for visualization of Entity detection importing displacy from spacy
from spacy import displacy
import nltk
# https://www.analyticsvidhya.com/blog/2019/02/stanfordnlp-nlp-library-python

# %%
# read playbook name
df_playbook = pd.read_csv('Playbook.csv')
playbook_name = df_playbook['name']

# drop empty cell
playbook_name = playbook_name.dropna()
# drop duplicates cells
playbook_name = playbook_name.drop_duplicates() 

# print(playbook_name.head())
# print('\n *********************************** \n')
# read task details
df_task = pd.read_csv('Task_playbook.csv')

# print(df_task.head())
# print('\n *********************************** \n')
task_plan = df_task['description']
# print(task_name.head(), '\n', len(task_name))
task_plan = task_plan.dropna()
task_plan = task_plan.drop_duplicates() 
# print(playbook_plan.head())
print('Number of playbook :', len(task_plan))
task_name = df_task['name']
# print(task_name.head(), '\n', len(task_name))

task_name = task_name.dropna()
# print('\n *********************************** \n')
# print(task_name.head(), '\n', len(task_name))
task_name = task_name.drop_duplicates() 
print('Number of Task: ', len(task_name))
# Out:
# Number of playbook : 767
# Number of Task:  1202

# %%
from IPython.core.display import display, HTML
list_sentence = []
from pathlib import Path


def tok_format(tok):
    return "_".join([tok.orth_, tok.tag_, tok.dep_])


def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(tok_format(node), [to_nltk_tree(child) for child in node.children])
    else:
        return tok_format(node)

# %%
# sentence tokenisation Load English tokenizer, tagger, parser, NER and word vectors
# nlp = English()

import en_core_web_sm
# import en_core_web_lg
from spacy.pipeline import Sentencizer
sentencizer = Sentencizer()
nlp = spacy.load("en_core_web_sm")

# Create the pipeline 'sentencizer' component
# sbd = nlp.create_pipe('sentencizer')
# Add the component to the pipeline
# nlp.add_pipe(sbd)
nlp.add_pipe(sentencizer, first=True)
# first separate the sentence in the playbok
sentence_list = []
for sentences in task_plan.values:
    # "nlp" Object is used to create documents with linguistic annotations.
    doc = nlp(sentences)
    # create list of sentence tokens
    for sent in doc.sents: 
        sentence_list.append(sent.text.lower())
        # print(sent.text, '\n')
print('Number of sentence in playbook: ', len(sentence_list))
# Out:
# Number of sentence in playbook:  1048

# %%
def display_dependency(doc):
    displacy.render(doc, style="dep", page=True, jupyter=True)
    # display(HTML(html))
    svg = displacy.render(doc, style="dep", jupyter=False)
    try:
        file_name = '-'.join([w.text for w in doc if not w.is_punct]) + ".svg"
        output_path = Path("image/" + file_name)
        output_path.open("w", encoding="utf-8").write(svg)
    except Exception as ex:
        print(ex)

# %%
playbook_declarative = pd.DataFrame(columns=['sentence', 'root_text', 'root_dep', 'root_pos', 'root_child', 'API'])
# root of the sentence and preposition of the sentence
for sentence in sentence_list:
    nlines = len(sentence.splitlines())
    nwords = len(sentence.split()) 
    if nlines < 2 and nwords > 2:
        doc = nlp(sentence)
        display_dependency(doc) # save the dependency parsing tree
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f925fd5df67e4dda93018b5fc1c1e153-0" class="displacy" width="1275" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">enrich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# ...
